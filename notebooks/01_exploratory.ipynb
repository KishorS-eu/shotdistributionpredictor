# %%
# 1. Environment & Path Setup
import sys
import os

# Add the project root directory to sys.path so 'pipeline' is importable
sys.path.append(os.path.abspath('..'))

import numpy as np
import pandas as pd
from statsbombpy import sb

from pipeline import (get_teams, get_team_matchids, get_lineup_events, get_shots_from_timeline,
                     get_teamseason_shot_events, get_allfeaturedplayers, get_playerusage,
                     get_uniquelineups)

# %%
competitions = sb.competitions()
compeititons_1516 = competitions[competitions["season_name"] == "2015/2016"]
# Out:
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %% [markdown]
# Premier League 15/16 Season
# competition_id = 2
# season_id = 27

# %%
display(get_teams(2, 27))
# Out:
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     home_team_id             home_team
# 0              1               Arsenal
# 1             22        Leicester City
# 2             23               Watford
# 3             24             Liverpool
# 4             25           Southampton
# 5             26          Swansea City
# 6             27  West Bromwich Albion
# 7             28       AFC Bournemouth
# 8             29               Everton
# 9             30            Stoke City
# 10            31        Crystal Palace
# 11            33               Chelsea
# 12            36       Manchester City
# 13            37      Newcastle United
# 14            38     Tottenham Hotspur
# 15            39     Manchester United
# 16            40       West Ham United
# 17            41            Sunderland
# ...

# %% [markdown]
# Arsenal:
# team_id = 1

# %%
arsenal_1516_matchids = get_team_matchids(2, 27, 1)
# Out:
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
arsenal_1516_shotevents = get_teamseason_shot_events(2, 27, 1)
# Out:
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Found 38 games for the season
# Processed shot event data for game 1/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# ...

# %%
arsenal_featureplayers = get_allfeaturedplayers(arsenal_1516_shotevents)

# %%
display(arsenal_featureplayers)
# Out:
# frozenset({('11386', 'Santiago Cazorla González'),
#            ('3385', 'Alexis Alejandro Sánchez Sánchez'),
#            ('3388', 'Jack Wilshere'),
#            ('3394', 'Laurent Koscielny'),
#            ('3437', 'Francis Joseph Coquelin'),
#            ('3461', 'Petr Čech'),
#            ('3475', 'Per Mertesacker'),
#            ('3496', 'Mesut Özil'),
#            ('3498', 'Ignacio Monreal Eraso'),
#            ('3511', 'Héctor Bellerín Moruno'),
#            ('3517', 'Aaron Ramsey'),
#            ('3525', 'Alex Oxlade-Chamberlain'),
#            ('3528', 'Kieran Gibbs'),
#            ('3568', 'Mohamed Naser Elsayed Elneny'),
#            ('3569', 'Daniel Nii Tackie Mensah Welbeck'),
#            ('3604', 'Olivier Giroud'),
#            ('3647', 'Alex Iwobi'),
#            ('3668', 'Theo Walcott'),
#            ('3713', 'Calum Chambers'),
#            ('42703', 'Mikel Arteta Amatriain'),
#            ('4276', 'David Ospina Ramírez'),
#            ('4428', 'Mathieu Debuchy'),
# ...

# %%
alexis_sanchez_usage = get_playerusage(get_uniquelineups(arsenal_1516_shotevents), 11386, 'Alexis Alejandro Sánchez Sánchez')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 alexis_sanchez_usage = get_playerusage(get_uniquelineups(arsenal_1516_shotevents), 11386, 'Alexis Alejandro Sánchez Sánchez')
#
# File ~/Projects/ShotDist/shotdistributionpredictor/pipeline/shotusage.py:77, in get_playerusage(processedshots_df, player_id, player_name)
#      72 sublist = [
#      73     (df, f_set) for df, f_set in processedshots_df
#      74     if (str(int(player_id)), player_name) in f_set
#      75 ]
#      76 subarray = np.array(sublist, dtype = object)
# ---> 77 new_df = pd.concat(list(subarray[:, 0]))
#      78 new_df = new_df[(~new_df['mandown'])]
#      79 player_df = new_df[(new_df['player_id'] == player_id)]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
