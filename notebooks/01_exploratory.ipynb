# %%
# 1. Environment & Path Setup
import os
import sys

# Add the project root directory to sys.path so 'pipeline' is importable
sys.path.append(os.path.abspath('..'))

import numpy as np  # noqa: F401
import pandas as pd  # noqa: F401
from statsbombpy import sb

from pipeline import (
    get_events_from_timeline,
    get_team_matchids,
    get_teams,
    get_teamseason_matchevents,
)

# %%
competitions = sb.competitions()
compeititons_1516 = competitions[competitions["season_name"] == "2015/2016"]
# Out:
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %% [markdown]
# Premier League 15/16 Season
# competition_id = 2
# season_id = 27

# %%
display(get_teams(2, 27))
# Out:
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     home_team_id             home_team
# 0              1               Arsenal
# 1             22        Leicester City
# 2             23               Watford
# 3             24             Liverpool
# 4             25           Southampton
# 5             26          Swansea City
# 6             27  West Bromwich Albion
# 7             28       AFC Bournemouth
# 8             29               Everton
# 9             30            Stoke City
# 10            31        Crystal Palace
# 11            33               Chelsea
# 12            36       Manchester City
# 13            37      Newcastle United
# 14            38     Tottenham Hotspur
# 15            39     Manchester United
# 16            40       West Ham United
# 17            41            Sunderland
# ...

# %% [markdown]
# Arsenal:
# team_id = 1

# %%
arsenal_1516_matchids = get_team_matchids(2, 27, 1)
# Out:
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
match_df = sb.events(match_id=3754117)
match_df = match_df[match_df['team_id'] == 1]
# Out:
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
ars_match_df = get_events_from_timeline(1, 3754117)
# Out:
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
display(ars_match_df[['type', 'period', 'timestamp', 'period_offset', 'match_time']])
# Out:
#                type  period              timestamp          period_offset  \
# 0       Starting XI       1        0 days 00:00:00        0 days 00:00:00
# 1        Half Start       1        0 days 00:00:00        0 days 00:00:00
# 2              Pass       1 0 days 00:00:00.375000        0 days 00:00:00
# 3     Ball Receipt*       1 0 days 00:00:02.042000        0 days 00:00:00
# 4              Pass       1 0 days 00:00:02.452000        0 days 00:00:00
# ...             ...     ...                    ...                    ...
# 1801  Ball Receipt*       2 0 days 00:48:44.771000 0 days 00:46:10.114000
# 1802           Pass       2 0 days 00:48:46.230000 0 days 00:46:10.114000
# 1803  Ball Receipt*       2 0 days 00:48:47.444000 0 days 00:46:10.114000
# 1804           Pass       2 0 days 00:49:13.923000 0 days 00:46:10.114000
# 1805       Half End       2 0 days 00:49:16.265000 0 days 00:46:10.114000
#
#                  match_time
# 0           0 days 00:00:00
# ...

# %%
ars_all_match_df = get_teamseason_matchevents(2, 27, 1)
# Out:
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Found 38 games for the season
# Processed match event data for game 1/38
# Processed match event data for game 2/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# ...
