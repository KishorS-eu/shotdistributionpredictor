# %%
# 1. Environment & Path Setup
import os
import sys

# Add the project root directory to sys.path so 'pipeline' is importable
sys.path.append(os.path.abspath('..'))

import numpy as np  # noqa: F401
import pandas as pd
from statsbombpy import sb  # noqa: F401

from pipeline import get_team_matchids, get_teamseason_matchevents

# %%
arsenal_1516_matchids = get_team_matchids(2, 27, 1)
display(arsenal_1516_matchids)
# Out:
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# [3754217,
#  3754117,
#  3754296,
#  3753983,
#  3754160,
#  3754129,
#  3754309,
#  3754041,
#  3754038,
#  3753999,
#  3754174,
#  3754171,
#  3754126,
#  3754205,
#  3754301,
#  3754240,
#  3754265,
#  3754312,
#  3754173,
#  3753976,
#  3753980,
#  3753990,
#  3754009,
#  3754069,
#  3754111,
#  3754118,
#  3754184,
#  3754201,
#  3754202,
#  3754239,
#  3754241,
#  3754253,
#  3754261,
#  3754284,
#  3754305,
#  3754314,
#  3754318,
#  3754141]

# %%
arsenal_1516_events = get_teamseason_matchevents(2, 27, 1)
# Out:
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Found 38 games for the season
# Processed match event data for game 1/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 2/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 3/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 4/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 5/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 6/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 7/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 8/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 9/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 10/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 11/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 12/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 13/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 14/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 15/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 16/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 17/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 18/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 19/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 20/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 21/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 22/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 23/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 24/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 25/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 26/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 27/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 28/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 29/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 30/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 31/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 32/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 33/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 34/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 35/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 36/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 37/38
# /home/kishor/Projects/ShotDist/shotdistributionpredictor/.venv/lib/python3.14/site-packages/statsbombpy/api_client.py:27: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processed match event data for game 38/38

# %%
event_types = arsenal_1516_events['type'].unique()

# %%
print(event_types)
# Out:
# <StringArray>
# [      'Starting XI',        'Half Start',              'Pass',
#      'Ball Receipt*',             'Carry',          'Pressure',
#      'Dribbled Past',    'Foul Committed',     'Ball Recovery',
#            'Dribble',        'Miscontrol',              'Shot',
#          'Clearance',              'Duel',            'Shield',
#           'Foul Won',       'Goal Keeper',      'Dispossessed',
#              'Block',      'Interception',   'Injury Stoppage',
#         'Player Off',         'Player On',     'Bad Behaviour',
#  'Referee Ball-Drop',    'Tactical Shift',          'Half End',
#       'Substitution',  'Own Goal Against',             'Error',
#              '50/50',      'Own Goal For',           'Offside']
# Length: 33, dtype: str

# %%
ipevents = ['Pass', 'Ball Receipt*', 'Carry', 'Dribble', 'Shot', 'Dispossessed', 'Offside', 'Miscontrol']
arsenal_ip_events = arsenal_1516_events[arsenal_1516_events['type'].isin(ipevents)]

# %%
unique_players = (
    arsenal_1516_events[["player", "player_id"]]
    .dropna()
    .drop_duplicates()
    .set_index("player_id")["player"]
    .to_dict()
)

# %%
len(unique_players)
# Out:
# 25

# %%
print(unique_players)
# Out:
# {3668.0: 'Theo Walcott', 3496.0: 'Mesut Özil', 11386.0: 'Santiago Cazorla González', 3517.0: 'Aaron Ramsey', 3385.0: 'Alexis Alejandro Sánchez Sánchez', 3498.0: 'Ignacio Monreal Eraso', 3394.0: 'Laurent Koscielny', 3437.0: 'Francis Joseph Coquelin', 6746.0: 'Gabriel Armando de Abreu', 3511.0: 'Héctor Bellerín Moruno', 3461.0: 'Petr Čech', 3713.0: 'Calum Chambers', 3525.0: 'Alex Oxlade-Chamberlain', 3604.0: 'Olivier Giroud', 6631.0: 'Mathieu Flamini', 3475.0: 'Per Mertesacker', 5581.0: 'Joel Nathaniel Campbell Samuels', 3528.0: 'Kieran Gibbs', 3647.0: 'Alex Iwobi', 3388.0: 'Jack Wilshere', 3568.0: 'Mohamed Naser Elsayed Elneny', 42703.0: 'Mikel Arteta Amatriain', 4428.0: 'Mathieu Debuchy', 3569.0: 'Daniel Nii Tackie Mensah Welbeck', 4276.0: 'David Ospina Ramírez'}

# %%
unique_player_matches = list(
    arsenal_1516_events[["match_id", "player_id"]]
    .dropna()
    .drop_duplicates()
    .itertuples(index=False, name=None)
)

# %%
len(unique_player_matches)
# Out:
# 524

# %%
pass_events = arsenal_1516_events[["pass_events"]]

# %% [markdown]
# 3385.0 - Alexis Sanchez

# %%
from mplsoccer import Pitch
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

player_events = arsenal_ip_events[
    arsenal_ip_events["player_id"].eq(3385.0)
].copy()

# Extract StatsBomb x/y coordinates from the location column
player_events[["x", "y"]] = pd.DataFrame(
    player_events["location"].tolist(),
    index=player_events.index
)

player_events = player_events.dropna(subset=["x", "y"])

event_types = sorted(player_events["type"].dropna().unique())

markers = ["o", "s", "^", "D", "P", "X", "v", "<", ">", "*", "h", "p"]
colors = plt.cm.tab20.colors

event_style = {
    event_type: {
        "marker": markers[index % len(markers)],
        "color": colors[index % len(colors)]
    }
    for index, event_type in enumerate(event_types)
}

match_ids = list(arsenal_1516_matchids)
columns = 4
rows = (len(match_ids) + columns - 1) // columns

fig, axes = plt.subplots(
    rows,
    columns,
    figsize=(18, rows * 5),
    squeeze=False
)

pitch = Pitch(
    pitch_type="statsbomb",
    pitch_color="#f7f4ed",
    line_color="#333333",
    linewidth=1
)

for index, match_id in enumerate(match_ids):
    ax = axes.flat[index]
    pitch.draw(ax=ax)

    match_events = player_events[
        player_events["match_id"].eq(match_id)
    ]

    for event_type in event_types:
        events = match_events[
            match_events["type"].eq(event_type)
        ]

        if events.empty:
            continue

        style = event_style[event_type]

        pitch.scatter(
            events["x"],
            events["y"],
            ax=ax,
            marker=style["marker"],
            s=90,
            color=style["color"],
            edgecolors="black",
            linewidth=0.5,
            alpha=0.9
        )

    ax.set_title(f"Match {match_id}", fontsize=10)

# Hide unused subplot axes
for ax in axes.flat[len(match_ids):]:
    ax.remove()

legend_handles = [
    Line2D(
        [0],
        [0],
        marker=event_style[event_type]["marker"],
        color="w",
        label=event_type,
        markerfacecolor=event_style[event_type]["color"],
        markeredgecolor="black",
        markersize=8
    )
    for event_type in event_types
]

fig.legend(
    handles=legend_handles,
    title="Event type",
    loc="center left",
    bbox_to_anchor=(0.91, 0.5)
)

fig.suptitle(
    "Player 3385.0 Events Across Arsenal Matches",
    fontsize=16,
    y=0.995
)

plt.tight_layout(rect=[0, 0, 0.9, 0.98])
plt.show()
